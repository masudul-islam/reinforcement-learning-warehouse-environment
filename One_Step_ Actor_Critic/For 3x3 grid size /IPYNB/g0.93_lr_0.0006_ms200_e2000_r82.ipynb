# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Warehouse Agent
class warehouse_agent:
    def __init__(self, rows, columns):
        # Actions: ['Up' 0, 'Right' 1, 'Down' 2, 'Left' 3]
        self.A = np.array([0, 1, 2, 3])
        # Transition function probabilities
        self.P = np.array([0.95, 0.97, 0.99, 1.0])  # Reduced stochasticity
        self.rows = rows
        self.columns = columns
        self.reward = None
        self.terminal_states = None
        self.H = None  # environment height
        self.W = None  # environment width
        self._generate_environment(rows, columns)

    def _generate_environment(self, rows, columns):
        # Initialize the grid environment
        self.H = 3 * rows + rows + 1
        self.W = 3 * columns + 2
        reward = -np.ones((self.H, self.W))
        reward[:, np.arange(1, self.W - 3, 3)] = -9  # Aisle separators
        reward[:, np.arange(3, self.W, 3)] = -9
        reward[np.arange(0, self.H, 4)] = -1  # Row separators
        reward[2, 2] = 100  # Set terminal state reward
        self.reward = reward

        # Terminal states at specific locations
        self.terminal_states = np.array([[2, 2]])

    def generate_ini_state(self, terminate_x, terminate_y):
        # Generate a random initial state that's not the terminal state
        while True:
            x = np.random.randint(0, self.H)
            y = np.random.randint(0, self.W)
            if (x, y) != (terminate_x, terminate_y) and self.reward[x, y] != -9:
                return [x, y]

    def apply_transition_function(self, intended_action):
        c = np.random.rand()
        if c < self.P[0]:  # Move in the intended direction
            return intended_action
        elif c < self.P[1]:  # Turn left
            return (intended_action - 1) % len(self.A)
        elif c < self.P[2]:  # Turn right
            return (intended_action + 1) % len(self.A)
        else:  # No action
            return None

    def computeNextPosition(self, row, col, action):
        if action is None:  # No action, stay in the same position
            return int(row), int(col)

        new_row, new_col = int(row), int(col)
        if action == 0:  # Up
            new_row -= 1
        elif action == 1:  # Right
            new_col += 1
        elif action == 2:  # Down
            new_row += 1
        elif action == 3:  # Left
            new_col -= 1

        # Check boundaries and walls
        if (
            new_row < 0
            or new_row >= self.H
            or new_col < 0
            or new_col >= self.W
            or self.reward[new_row, new_col] == -9
        ):
            return int(row), int(col)  # Stay in the same position if invalid move
        return int(new_row), int(new_col)

# Actor-Critic Model
class ActorCriticModel(tf.keras.Model):
    def __init__(self, num_actions):
        super(ActorCriticModel, self).__init__()
        self.common = layers.Dense(128, activation="relu")
        self.actor = layers.Dense(num_actions, activation="softmax")
        self.critic = layers.Dense(1)

    def call(self, inputs):
        x = self.common(inputs)
        return self.actor(x), self.critic(x)


# Training Function
def train_actor_critic(agent, model, episodes=500, gamma=0.93, learning_rate=0.0006, max_steps=200):
    optimizer = tf.keras.optimizers.Adam(learning_rate)
    total_rewards = []

    for episode in range(episodes):
        # Reset environment
        start_state = agent.generate_ini_state(agent.terminal_states[0][0], agent.terminal_states[0][1])
        state = np.array(start_state, dtype=np.float32)
        state = np.expand_dims(state, axis=0)

        episode_reward = 0
        done = False
        steps = 0

        while not done and steps < max_steps:
            steps += 1
            with tf.GradientTape() as tape:
                action_probs, state_value = model(state)

                # Choose action
                action = np.random.choice(len(agent.A), p=np.squeeze(action_probs))

                # Simulate environment step
                real_action = agent.apply_transition_function(action)
                next_state = agent.computeNextPosition(state[0, 0], state[0, 1], real_action)
                reward = agent.reward[next_state[0], next_state[1]]
                done = (np.array(next_state) == agent.terminal_states[0]).all()

                next_state = np.array(next_state, dtype=np.float32)
                next_state = np.expand_dims(next_state, axis=0)

                _, next_state_value = model(next_state)
                target = reward + gamma * next_state_value * (1 - int(done))
                td_error = target - state_value

                actor_loss = -tf.math.log(action_probs[0, action]) * td_error
                critic_loss = tf.square(td_error)
                loss = actor_loss + critic_loss

            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

            state = next_state
            episode_reward += reward

        total_rewards.append(episode_reward)
        if episode % 10 == 0:
            avg_reward = np.mean(total_rewards[-10:])
            print(f"Episode {episode}: Average Reward = {avg_reward:.2f}")

    return total_rewards

# Generate Learned Policy
def generate_learned_policy(agent, model):
    policy = np.full((agent.H, agent.W), -1)
    for row in range(agent.H):
        for col in range(agent.W):
            if agent.reward[row, col] == -9:  # Skip walls
                continue
            state = np.expand_dims(np.array([row, col], dtype=np.float32), axis=0)
            action_probs, _ = model(state)
            best_action = np.argmax(action_probs)
            policy[row, col] = best_action
    return policy

# Display Policy
def display_policy(agent, policy):
    action_map = {0: "↑", 1: "→", 2: "↓", 3: "←", -1: "█"}
    visual = np.empty(policy.shape, dtype=str)
    for row in range(agent.H):
        for col in range(agent.W):
            visual[row, col] = action_map[policy[row, col]]
    for row in visual:
        print(" ".join(row))

# Heatmap of Policy
def plot_heatmap(agent, policy):
    plt.figure(figsize=(10, 6))
    plt.imshow(policy, cmap="viridis", interpolation="nearest")
    plt.colorbar(label="Action Index")
    plt.title("Heatmap of Learned Policy")
    plt.show()

# Testing Function
def test_policy(agent, model):
    start_state = agent.generate_ini_state(agent.terminal_states[0][0], agent.terminal_states[0][1])
    state = np.array(start_state, dtype=np.float32)
    state = np.expand_dims(state, axis=0)
    done = False
    total_reward = 0

    while not done:
        action_probs, _ = model(state)
        action = np.argmax(action_probs)

        real_action = agent.apply_transition_function(action)
        next_state = agent.computeNextPosition(state[0, 0], state[0, 1], real_action)
        reward = agent.reward[next_state[0], next_state[1]]
        done = (np.array(next_state) == agent.terminal_states[0]).all()

        total_reward += reward
        state = np.expand_dims(np.array(next_state, dtype=np.float32), axis=0)
        print(f"State: {next_state}, Reward: {reward}")

    print(f"Total Test Reward: {total_reward}")
    return total_reward

# Plot Rewards
def plot_rewards(rewards):
    plt.plot(rewards)
    plt.xlabel('Episodes')
    plt.ylabel('Rewards')
    plt.title('Training Progress')
    plt.show()

# Main Script
if __name__ == "__main__":
    # Initialize warehouse agent
    agent = warehouse_agent(rows=3, columns=3)  # Set up a 3x3 aisle environment

    num_actions = len(agent.A)
    model = ActorCriticModel(num_actions)

    print("Training Actor-Critic...")
    rewards = train_actor_critic(agent, model, episodes=2000)

    print("Testing the learned policy...")
    test_policy(agent, model)

    print("Generating learned policy...")
    learned_policy = generate_learned_policy(agent, model)

    print("Displaying learned policy...")
    display_policy(agent, learned_policy)

    print("Plotting heatmap of learned policy...")
    plot_heatmap(agent, learned_policy)

    plot_rewards(rewards)
# Out:
# Training Actor-Critic...
# Episode 0: Average Reward = -200.00
# Episode 10: Average Reward = -69.00
# Episode 20: Average Reward = -93.20
# Episode 30: Average Reward = -71.70
# Episode 40: Average Reward = -23.30
# Episode 50: Average Reward = -127.60
# Episode 60: Average Reward = -153.20
# Episode 70: Average Reward = -83.80
# Episode 80: Average Reward = -88.00
# Episode 90: Average Reward = -170.00
# Episode 100: Average Reward = -141.00
# Episode 110: Average Reward = -83.40
# Episode 120: Average Reward = -106.60
# Episode 130: Average Reward = 25.30
# Episode 140: Average Reward = -142.50
# Episode 150: Average Reward = -99.60
# Episode 160: Average Reward = -117.50
# Episode 170: Average Reward = -87.40
# Episode 180: Average Reward = -66.70
# Episode 190: Average Reward = -75.70
# Episode 200: Average Reward = -59.80
# Episode 210: Average Reward = -87.50
# Episode 220: Average Reward = -78.70
# Episode 230: Average Reward = -34.10
# Episode 240: Average Reward = -86.40
# Episode 250: Average Reward = -12.90
# Episode 260: Average Reward = -23.00
# Episode 270: Average Reward = 23.20
# Episode 280: Average Reward = -5.80
# Episode 290: Average Reward = 71.80
# Episode 300: Average Reward = 1.60
# Episode 310: Average Reward = -21.50
# Episode 320: Average Reward = 46.30
# Episode 330: Average Reward = 60.90
# Episode 340: Average Reward = 13.90
# Episode 350: Average Reward = -58.90
# Episode 360: Average Reward = 24.50
# Episode 370: Average Reward = -47.70
# Episode 380: Average Reward = 12.80
# Episode 390: Average Reward = 11.50
# Episode 400: Average Reward = -13.10
# Episode 410: Average Reward = -14.60
# Episode 420: Average Reward = 5.70
# Episode 430: Average Reward = 40.80
# Episode 440: Average Reward = 30.70
# Episode 450: Average Reward = 40.80
# Episode 460: Average Reward = -2.80
# Episode 470: Average Reward = 85.40
# Episode 480: Average Reward = 81.40
# Episode 490: Average Reward = -21.20
# Episode 500: Average Reward = 46.90
# Episode 510: Average Reward = 57.70
# Episode 520: Average Reward = 46.90
# Episode 530: Average Reward = -83.60
# Episode 540: Average Reward = 49.80
# Episode 550: Average Reward = -52.80
# Episode 560: Average Reward = 29.60
# Episode 570: Average Reward = 7.60
# Episode 580: Average Reward = 51.60
# Episode 590: Average Reward = 16.20
# Episode 600: Average Reward = 55.30
# Episode 610: Average Reward = 14.30
# Episode 620: Average Reward = 8.20
# Episode 630: Average Reward = 44.20
# Episode 640: Average Reward = 74.30
# Episode 650: Average Reward = 51.10
# Episode 660: Average Reward = 24.50
# Episode 670: Average Reward = 67.80
# Episode 680: Average Reward = 44.50
# Episode 690: Average Reward = 43.80
# Episode 700: Average Reward = 46.30
# Episode 710: Average Reward = 58.90
# Episode 720: Average Reward = 14.00
# Episode 730: Average Reward = 0.10
# Episode 740: Average Reward = 20.60
# Episode 750: Average Reward = 54.80
# Episode 760: Average Reward = 65.50
# Episode 770: Average Reward = 31.80
# Episode 780: Average Reward = 48.90
# Episode 790: Average Reward = 27.00
# Episode 800: Average Reward = 59.60
# Episode 810: Average Reward = 70.40
# Episode 820: Average Reward = 26.40
# Episode 830: Average Reward = 10.60
# Episode 840: Average Reward = 34.00
# Episode 850: Average Reward = 48.00
# Episode 860: Average Reward = 32.20
# Episode 870: Average Reward = 72.40
# Episode 880: Average Reward = 25.10
# Episode 890: Average Reward = 69.60
# Episode 900: Average Reward = 53.10
# Episode 910: Average Reward = 50.60
# Episode 920: Average Reward = 34.50
# Episode 930: Average Reward = -14.20
# Episode 940: Average Reward = 65.20
# Episode 950: Average Reward = 44.00
# Episode 960: Average Reward = 27.00
# Episode 970: Average Reward = 21.40
# Episode 980: Average Reward = 70.60
# Episode 990: Average Reward = 69.70
# Episode 1000: Average Reward = 31.40
# Episode 1010: Average Reward = 58.10
# Episode 1020: Average Reward = 77.20
# Episode 1030: Average Reward = 31.70
# Episode 1040: Average Reward = 90.10
# Episode 1050: Average Reward = 78.70
# Episode 1060: Average Reward = 14.60
# Episode 1070: Average Reward = 71.50
# Episode 1080: Average Reward = 51.70
# Episode 1090: Average Reward = 51.20
# Episode 1100: Average Reward = 55.20
# Episode 1110: Average Reward = 18.70
# Episode 1120: Average Reward = 65.90
# Episode 1130: Average Reward = 40.20
# Episode 1140: Average Reward = 19.60
# Episode 1150: Average Reward = 41.30
# Episode 1160: Average Reward = 14.20
# Episode 1170: Average Reward = 67.30
# Episode 1180: Average Reward = 82.20
# Episode 1190: Average Reward = 66.30
# Episode 1200: Average Reward = 69.50
# Episode 1210: Average Reward = 20.50
# Episode 1220: Average Reward = 47.90
# Episode 1230: Average Reward = 46.70
# Episode 1240: Average Reward = 0.40
# Episode 1250: Average Reward = 55.20
# Episode 1260: Average Reward = 87.80
# Episode 1270: Average Reward = 64.80
# Episode 1280: Average Reward = 54.40
# Episode 1290: Average Reward = 22.30
# Episode 1300: Average Reward = 28.20
# Episode 1310: Average Reward = 39.60
# Episode 1320: Average Reward = 83.90
# Episode 1330: Average Reward = 58.00
# Episode 1340: Average Reward = 53.80
# Episode 1350: Average Reward = 31.30
# Episode 1360: Average Reward = 46.10
# Episode 1370: Average Reward = 48.60
# Episode 1380: Average Reward = 60.00
# Episode 1390: Average Reward = 57.50
# Episode 1400: Average Reward = 32.70
# Episode 1410: Average Reward = 69.10
# Episode 1420: Average Reward = 74.90
# Episode 1430: Average Reward = 62.40
# Episode 1440: Average Reward = 63.00
# Episode 1450: Average Reward = 72.10
# Episode 1460: Average Reward = 80.30
# Episode 1470: Average Reward = 43.70
# Episode 1480: Average Reward = 72.80
# Episode 1490: Average Reward = 37.90
# Episode 1500: Average Reward = 56.10
# Episode 1510: Average Reward = 33.40
# Episode 1520: Average Reward = 63.80
# Episode 1530: Average Reward = 48.00
# Episode 1540: Average Reward = 22.70
# Episode 1550: Average Reward = 38.70
# Episode 1560: Average Reward = 32.30
# Episode 1570: Average Reward = 63.10
# Episode 1580: Average Reward = 36.60
# Episode 1590: Average Reward = 68.30
# Episode 1600: Average Reward = 27.60
# Episode 1610: Average Reward = 58.40
# Episode 1620: Average Reward = 76.00
# Episode 1630: Average Reward = 78.00
# Episode 1640: Average Reward = 46.70
# Episode 1650: Average Reward = 57.10
# Episode 1660: Average Reward = 51.00
# Episode 1670: Average Reward = 56.10
# Episode 1680: Average Reward = 51.60
# Episode 1690: Average Reward = 52.90
# Episode 1700: Average Reward = 63.20
# Episode 1710: Average Reward = 68.10
# Episode 1720: Average Reward = 89.60
# Episode 1730: Average Reward = 70.70
# Episode 1740: Average Reward = 82.10
# Episode 1750: Average Reward = 73.80
# Episode 1760: Average Reward = 59.10
# Episode 1770: Average Reward = 52.50
# Episode 1780: Average Reward = 41.90
# Episode 1790: Average Reward = 72.80
# Episode 1800: Average Reward = 11.40
# Episode 1810: Average Reward = 71.40
# Episode 1820: Average Reward = 87.90
# Episode 1830: Average Reward = 79.90
# Episode 1840: Average Reward = 40.10
# Episode 1850: Average Reward = 33.40
# Episode 1860: Average Reward = 71.70
# Episode 1870: Average Reward = 68.60
# Episode 1880: Average Reward = 75.70
# Episode 1890: Average Reward = 36.70
# Episode 1900: Average Reward = 48.10
# Episode 1910: Average Reward = 26.90
# Episode 1920: Average Reward = 63.50
# Episode 1930: Average Reward = 44.50
# Episode 1940: Average Reward = 57.30
# Episode 1950: Average Reward = 30.20
# Episode 1960: Average Reward = 17.70
# Episode 1970: Average Reward = 34.60
# Episode 1980: Average Reward = 65.60
# Episode 1990: Average Reward = 47.00
# Testing the learned policy...
# State: (5, 10), Reward: -1.0
# State: (5, 10), Reward: -1.0
# State: (5, 10), Reward: -1.0
# State: (5, 10), Reward: -1.0
# State: (5, 10), Reward: -1.0
# State: (5, 10), Reward: -1.0
# State: (5, 10), Reward: -1.0
# State: (5, 10), Reward: -1.0
# State: (4, 10), Reward: -1.0
# State: (4, 9), Reward: -1.0
# State: (4, 8), Reward: -1.0
# State: (4, 7), Reward: -1.0
# State: (4, 6), Reward: -1.0
# State: (4, 5), Reward: -1.0
# State: (4, 4), Reward: -1.0
# State: (4, 3), Reward: -1.0
# State: (4, 2), Reward: -1.0
# State: (3, 2), Reward: -1.0
# State: (2, 2), Reward: 100.0
# Total Test Reward: 82.0
# Generating learned policy...
# Displaying learned policy...
# → → ↓ ↓ ← ← ← ← ← ← ←
# → █ ↓ █ █ ← █ █ ← █ ←
# ↑ █ ↓ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ ↑ ↑ ← ← ← ← ← ← ← ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ ↑ ↑ ← ← ← ← ← ← ← ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ ↑ ↑ ↑ ← ← ← ← ← ← ←
# Plotting heatmap of learned policy...
