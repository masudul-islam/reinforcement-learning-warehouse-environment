# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Warehouse Agent
class warehouse_agent:
    def __init__(self, rows, columns):
        # Actions: ['Up' 0, 'Right' 1, 'Down' 2, 'Left' 3]
        self.A = np.array([0, 1, 2, 3])
        # Transition function probabilities
        self.P = np.array([0.95, 0.97, 0.99, 1.0])  # Reduced stochasticity
        self.rows = rows
        self.columns = columns
        self.reward = None
        self.terminal_states = None
        self.H = None  # environment height
        self.W = None  # environment width
        self._generate_environment(rows, columns)

    def _generate_environment(self, rows, columns):
        # Initialize the grid environment
        self.H = 3 * rows + rows + 1
        self.W = 3 * columns + 2
        reward = -np.ones((self.H, self.W))
        reward[:, np.arange(1, self.W - 3, 3)] = -9  # Aisle separators
        reward[:, np.arange(3, self.W, 3)] = -9
        reward[np.arange(0, self.H, 4)] = -1  # Row separators
        reward[2, 2] = 100  # Set terminal state reward
        self.reward = reward

        # Terminal states at specific locations
        self.terminal_states = np.array([[2, 2]])

    def generate_ini_state(self, terminate_x, terminate_y):
        # Generate a random initial state that's not the terminal state
        while True:
            x = np.random.randint(0, self.H)
            y = np.random.randint(0, self.W)
            if (x, y) != (terminate_x, terminate_y) and self.reward[x, y] != -9:
                return [x, y]

    def apply_transition_function(self, intended_action):
        c = np.random.rand()
        if c < self.P[0]:  # Move in the intended direction
            return intended_action
        elif c < self.P[1]:  # Turn left
            return (intended_action - 1) % len(self.A)
        elif c < self.P[2]:  # Turn right
            return (intended_action + 1) % len(self.A)
        else:  # No action
            return None

    def computeNextPosition(self, row, col, action):
        if action is None:  # No action, stay in the same position
            return int(row), int(col)

        new_row, new_col = int(row), int(col)
        if action == 0:  # Up
            new_row -= 1
        elif action == 1:  # Right
            new_col += 1
        elif action == 2:  # Down
            new_row += 1
        elif action == 3:  # Left
            new_col -= 1

        # Check boundaries and walls
        if (
            new_row < 0
            or new_row >= self.H
            or new_col < 0
            or new_col >= self.W
            or self.reward[new_row, new_col] == -9
        ):
            return int(row), int(col)  # Stay in the same position if invalid move
        return int(new_row), int(new_col)

# Actor-Critic Model
class ActorCriticModel(tf.keras.Model):
    def __init__(self, num_actions):
        super(ActorCriticModel, self).__init__()
        self.common = layers.Dense(128, activation="relu")
        self.actor = layers.Dense(num_actions, activation="softmax")
        self.critic = layers.Dense(1)

    def call(self, inputs):
        x = self.common(inputs)
        return self.actor(x), self.critic(x)


# Training Function
def train_actor_critic(agent, model, episodes=500, gamma=0.95, learning_rate=0.0007, max_steps=200):
    optimizer = tf.keras.optimizers.Adam(learning_rate)
    total_rewards = []

    for episode in range(episodes):
        # Reset environment
        start_state = agent.generate_ini_state(agent.terminal_states[0][0], agent.terminal_states[0][1])
        state = np.array(start_state, dtype=np.float32)
        state = np.expand_dims(state, axis=0)

        episode_reward = 0
        done = False
        steps = 0

        while not done and steps < max_steps:
            steps += 1
            with tf.GradientTape() as tape:
                action_probs, state_value = model(state)

                # Choose action
                action = np.random.choice(len(agent.A), p=np.squeeze(action_probs))

                # Simulate environment step
                real_action = agent.apply_transition_function(action)
                next_state = agent.computeNextPosition(state[0, 0], state[0, 1], real_action)
                reward = agent.reward[next_state[0], next_state[1]]
                done = (np.array(next_state) == agent.terminal_states[0]).all()

                next_state = np.array(next_state, dtype=np.float32)
                next_state = np.expand_dims(next_state, axis=0)

                _, next_state_value = model(next_state)
                target = reward + gamma * next_state_value * (1 - int(done))
                td_error = target - state_value

                actor_loss = -tf.math.log(action_probs[0, action]) * td_error
                critic_loss = tf.square(td_error)
                loss = actor_loss + critic_loss

            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

            state = next_state
            episode_reward += reward

        total_rewards.append(episode_reward)
        if episode % 10 == 0:
            avg_reward = np.mean(total_rewards[-10:])
            print(f"Episode {episode}: Average Reward = {avg_reward:.2f}")

    return total_rewards

# Generate Learned Policy
def generate_learned_policy(agent, model):
    policy = np.full((agent.H, agent.W), -1)
    for row in range(agent.H):
        for col in range(agent.W):
            if agent.reward[row, col] == -9:  # Skip walls
                continue
            state = np.expand_dims(np.array([row, col], dtype=np.float32), axis=0)
            action_probs, _ = model(state)
            best_action = np.argmax(action_probs)
            policy[row, col] = best_action
    return policy

# Display Policy
def display_policy(agent, policy):
    action_map = {0: "↑", 1: "→", 2: "↓", 3: "←", -1: "█"}
    visual = np.empty(policy.shape, dtype=str)
    for row in range(agent.H):
        for col in range(agent.W):
            visual[row, col] = action_map[policy[row, col]]
    for row in visual:
        print(" ".join(row))

# Heatmap of Policy
def plot_heatmap(agent, policy):
    plt.figure(figsize=(10, 6))
    plt.imshow(policy, cmap="viridis", interpolation="nearest")
    plt.colorbar(label="Action Index")
    plt.title("Heatmap of Learned Policy")
    plt.show()

# Testing Function
def test_policy(agent, model):
    start_state = agent.generate_ini_state(agent.terminal_states[0][0], agent.terminal_states[0][1])
    state = np.array(start_state, dtype=np.float32)
    state = np.expand_dims(state, axis=0)
    done = False
    total_reward = 0

    while not done:
        action_probs, _ = model(state)
        action = np.argmax(action_probs)

        real_action = agent.apply_transition_function(action)
        next_state = agent.computeNextPosition(state[0, 0], state[0, 1], real_action)
        reward = agent.reward[next_state[0], next_state[1]]
        done = (np.array(next_state) == agent.terminal_states[0]).all()

        total_reward += reward
        state = np.expand_dims(np.array(next_state, dtype=np.float32), axis=0)
        print(f"State: {next_state}, Reward: {reward}")

    print(f"Total Test Reward: {total_reward}")
    return total_reward

# Plot Rewards
def plot_rewards(rewards):
    plt.plot(rewards)
    plt.xlabel('Episodes')
    plt.ylabel('Rewards')
    plt.title('Training Progress')
    plt.show()

# Main Script
if __name__ == "__main__":
    # Initialize warehouse agent
    agent = warehouse_agent(rows=3, columns=3)  # Set up a 3x3 aisle environment

    num_actions = len(agent.A)
    model = ActorCriticModel(num_actions)

    print("Training Actor-Critic...")
    rewards = train_actor_critic(agent, model, episodes=2000)

    print("Testing the learned policy...")
    test_policy(agent, model)

    print("Generating learned policy...")
    learned_policy = generate_learned_policy(agent, model)

    print("Displaying learned policy...")
    display_policy(agent, learned_policy)

    print("Plotting heatmap of learned policy...")
    plot_heatmap(agent, learned_policy)

    plot_rewards(rewards)
# Out:
# Training Actor-Critic...
# Episode 0: Average Reward = -200.00
# Episode 10: Average Reward = -50.90
# Episode 20: Average Reward = -34.70
# Episode 30: Average Reward = -110.90
# Episode 40: Average Reward = -34.60
# Episode 50: Average Reward = -99.70
# Episode 60: Average Reward = -65.40
# Episode 70: Average Reward = -95.20
# Episode 80: Average Reward = -152.20
# Episode 90: Average Reward = -37.60
# Episode 100: Average Reward = -89.70
# Episode 110: Average Reward = -119.80
# Episode 120: Average Reward = -130.80
# Episode 130: Average Reward = -32.70
# Episode 140: Average Reward = -129.10
# Episode 150: Average Reward = -90.30
# Episode 160: Average Reward = -119.80
# Episode 170: Average Reward = -176.70
# Episode 180: Average Reward = -99.70
# Episode 190: Average Reward = -108.60
# Episode 200: Average Reward = -83.10
# Episode 210: Average Reward = -117.20
# Episode 220: Average Reward = -132.80
# Episode 230: Average Reward = -127.50
# Episode 240: Average Reward = -151.90
# Episode 250: Average Reward = -73.30
# Episode 260: Average Reward = -96.80
# Episode 270: Average Reward = -70.70
# Episode 280: Average Reward = -90.70
# Episode 290: Average Reward = -112.80
# Episode 300: Average Reward = -122.20
# Episode 310: Average Reward = -39.10
# Episode 320: Average Reward = 69.50
# Episode 330: Average Reward = -42.60
# Episode 340: Average Reward = -66.50
# Episode 350: Average Reward = 35.10
# Episode 360: Average Reward = -0.70
# Episode 370: Average Reward = -40.60
# Episode 380: Average Reward = -39.80
# Episode 390: Average Reward = 44.70
# Episode 400: Average Reward = 15.10
# Episode 410: Average Reward = -36.90
# Episode 420: Average Reward = 36.40
# Episode 430: Average Reward = 21.90
# Episode 440: Average Reward = 4.60
# Episode 450: Average Reward = 29.40
# Episode 460: Average Reward = 22.70
# Episode 470: Average Reward = 34.20
# Episode 480: Average Reward = 24.30
# Episode 490: Average Reward = 15.70
# Episode 500: Average Reward = 33.10
# Episode 510: Average Reward = 48.60
# Episode 520: Average Reward = 69.90
# Episode 530: Average Reward = 2.90
# Episode 540: Average Reward = 46.10
# Episode 550: Average Reward = 71.20
# Episode 560: Average Reward = 46.00
# Episode 570: Average Reward = 50.10
# Episode 580: Average Reward = 74.70
# Episode 590: Average Reward = 74.50
# Episode 600: Average Reward = 58.30
# Episode 610: Average Reward = 38.50
# Episode 620: Average Reward = 24.10
# Episode 630: Average Reward = 57.60
# Episode 640: Average Reward = 52.20
# Episode 650: Average Reward = 58.80
# Episode 660: Average Reward = 36.60
# Episode 670: Average Reward = 63.60
# Episode 680: Average Reward = 69.20
# Episode 690: Average Reward = 58.20
# Episode 700: Average Reward = 25.40
# Episode 710: Average Reward = 33.50
# Episode 720: Average Reward = 65.80
# Episode 730: Average Reward = 65.00
# Episode 740: Average Reward = 15.00
# Episode 750: Average Reward = 67.30
# Episode 760: Average Reward = 79.30
# Episode 770: Average Reward = 56.60
# Episode 780: Average Reward = 27.60
# Episode 790: Average Reward = 40.20
# Episode 800: Average Reward = 54.10
# Episode 810: Average Reward = 47.80
# Episode 820: Average Reward = 86.80
# Episode 830: Average Reward = 85.60
# Episode 840: Average Reward = 64.30
# Episode 850: Average Reward = 8.60
# Episode 860: Average Reward = 57.60
# Episode 870: Average Reward = 39.50
# Episode 880: Average Reward = 25.70
# Episode 890: Average Reward = 22.70
# Episode 900: Average Reward = 61.50
# Episode 910: Average Reward = 37.80
# Episode 920: Average Reward = 61.90
# Episode 930: Average Reward = 59.90
# Episode 940: Average Reward = 69.30
# Episode 950: Average Reward = 57.20
# Episode 960: Average Reward = 76.60
# Episode 970: Average Reward = 89.00
# Episode 980: Average Reward = 24.20
# Episode 990: Average Reward = 63.10
# Episode 1000: Average Reward = 65.10
# Episode 1010: Average Reward = 51.60
# Episode 1020: Average Reward = 43.40
# Episode 1030: Average Reward = 30.00
# Episode 1040: Average Reward = 84.80
# Episode 1050: Average Reward = 59.90
# Episode 1060: Average Reward = 31.50
# Episode 1070: Average Reward = 75.50
# Episode 1080: Average Reward = 52.10
# Episode 1090: Average Reward = 78.50
# Episode 1100: Average Reward = 84.40
# Episode 1110: Average Reward = 63.00
# Episode 1120: Average Reward = 19.90
# Episode 1130: Average Reward = 86.50
# Episode 1140: Average Reward = 53.60
# Episode 1150: Average Reward = 13.40
# Episode 1160: Average Reward = 12.50
# Episode 1170: Average Reward = 77.80
# Episode 1180: Average Reward = 78.00
# Episode 1190: Average Reward = 53.90
# Episode 1200: Average Reward = 46.20
# Episode 1210: Average Reward = -9.50
# Episode 1220: Average Reward = 42.00
# Episode 1230: Average Reward = 63.50
# Episode 1240: Average Reward = 79.70
# Episode 1250: Average Reward = 30.40
# Episode 1260: Average Reward = 44.10
# Episode 1270: Average Reward = 68.60
# Episode 1280: Average Reward = 56.60
# Episode 1290: Average Reward = 17.30
# Episode 1300: Average Reward = 53.00
# Episode 1310: Average Reward = 83.00
# Episode 1320: Average Reward = 53.60
# Episode 1330: Average Reward = 79.40
# Episode 1340: Average Reward = 66.80
# Episode 1350: Average Reward = 55.30
# Episode 1360: Average Reward = 20.40
# Episode 1370: Average Reward = 83.50
# Episode 1380: Average Reward = 86.00
# Episode 1390: Average Reward = 0.30
# Episode 1400: Average Reward = 68.50
# Episode 1410: Average Reward = 53.80
# Episode 1420: Average Reward = 65.60
# Episode 1430: Average Reward = 80.90
# Episode 1440: Average Reward = 41.50
# Episode 1450: Average Reward = 52.70
# Episode 1460: Average Reward = 55.80
# Episode 1470: Average Reward = 37.30
# Episode 1480: Average Reward = 39.80
# Episode 1490: Average Reward = 59.90
# Episode 1500: Average Reward = 31.90
# Episode 1510: Average Reward = 12.60
# Episode 1520: Average Reward = 75.90
# Episode 1530: Average Reward = 39.80
# Episode 1540: Average Reward = 23.20
# Episode 1550: Average Reward = 33.90
# Episode 1560: Average Reward = 37.00
# Episode 1570: Average Reward = 41.70
# Episode 1580: Average Reward = 39.80
# Episode 1590: Average Reward = 79.30
# Episode 1600: Average Reward = 27.90
# Episode 1610: Average Reward = 48.10
# Episode 1620: Average Reward = 86.10
# Episode 1630: Average Reward = 34.90
# Episode 1640: Average Reward = 84.50
# Episode 1650: Average Reward = 65.60
# Episode 1660: Average Reward = 76.60
# Episode 1670: Average Reward = 85.80
# Episode 1680: Average Reward = 65.60
# Episode 1690: Average Reward = 27.00
# Episode 1700: Average Reward = 55.80
# Episode 1710: Average Reward = 65.80
# Episode 1720: Average Reward = 71.80
# Episode 1730: Average Reward = 18.00
# Episode 1740: Average Reward = 70.60
# Episode 1750: Average Reward = 52.00
# Episode 1760: Average Reward = 50.50
# Episode 1770: Average Reward = 62.40
# Episode 1780: Average Reward = 51.50
# Episode 1790: Average Reward = 51.70
# Episode 1800: Average Reward = 52.20
# Episode 1810: Average Reward = 57.40
# Episode 1820: Average Reward = 39.00
# Episode 1830: Average Reward = 74.00
# Episode 1840: Average Reward = 45.20
# Episode 1850: Average Reward = 26.40
# Episode 1860: Average Reward = 44.20
# Episode 1870: Average Reward = 57.70
# Episode 1880: Average Reward = 72.70
# Episode 1890: Average Reward = 76.10
# Episode 1900: Average Reward = 85.60
# Episode 1910: Average Reward = 77.70
# Episode 1920: Average Reward = 47.20
# Episode 1930: Average Reward = 72.30
# Episode 1940: Average Reward = 57.40
# Episode 1950: Average Reward = 34.50
# Episode 1960: Average Reward = 87.70
# Episode 1970: Average Reward = 67.00
# Episode 1980: Average Reward = 90.10
# Episode 1990: Average Reward = 73.70
# Testing the learned policy...
# State: (0, 2), Reward: -1.0
# State: (1, 2), Reward: -1.0
# State: (2, 2), Reward: 100.0
# Total Test Reward: 98.0
# Generating learned policy...
# Displaying learned policy...
# → → ↓ ← ← ← ← ← ← ← ←
# ↑ █ ↓ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ ↑ ↑ ← ← ← ← ← ← ← ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ ↑ ↑ ← ← ← ← ← ← ← ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ █ ← █ ←
# ↑ ↑ ↑ ← ← ← ← ← ← ← ←
# Plotting heatmap of learned policy...
