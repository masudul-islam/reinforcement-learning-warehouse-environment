# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Warehouse Agent
class warehouse_agent:
    def __init__(self, rows, columns):
        # Actions: ['Up' 0, 'Right' 1, 'Down' 2, 'Left' 3]
        self.A = np.array([0, 1, 2, 3])
        # Transition function probabilities
        self.P = np.array([0.95, 0.97, 0.99, 1.0])  # Reduced stochasticity
        self.rows = rows
        self.columns = columns
        self.reward = None
        self.terminal_states = None
        self.H = None  # environment height
        self.W = None  # environment width
        self._generate_environment(rows, columns)

    def _generate_environment(self, rows, columns):
        # Initialize the grid environment
        self.H = 3 * rows + rows + 1
        self.W = 3 * columns + 2
        reward = -np.ones((self.H, self.W))
        reward[:, np.arange(1, self.W - 3, 3)] = -9  # Aisle separators
        reward[:, np.arange(3, self.W, 3)] = -9
        reward[np.arange(0, self.H, 4)] = -1  # Row separators
        reward[2, 2] = 100  # Set terminal state reward
        self.reward = reward

        # Terminal states at specific locations
        self.terminal_states = np.array([[2, 2]])

    def generate_ini_state(self, terminate_x, terminate_y):
        # Generate a random initial state that's not the terminal state
        while True:
            x = np.random.randint(0, self.H)
            y = np.random.randint(0, self.W)
            if (x, y) != (terminate_x, terminate_y) and self.reward[x, y] != -9:
                return [x, y]

    def apply_transition_function(self, intended_action):
        c = np.random.rand()
        if c < self.P[0]:  # Move in the intended direction
            return intended_action
        elif c < self.P[1]:  # Turn left
            return (intended_action - 1) % len(self.A)
        elif c < self.P[2]:  # Turn right
            return (intended_action + 1) % len(self.A)
        else:  # No action
            return None

    def computeNextPosition(self, row, col, action):
        if action is None:  # No action, stay in the same position
            return int(row), int(col)

        new_row, new_col = int(row), int(col)
        if action == 0:  # Up
            new_row -= 1
        elif action == 1:  # Right
            new_col += 1
        elif action == 2:  # Down
            new_row += 1
        elif action == 3:  # Left
            new_col -= 1

        # Check boundaries and walls
        if (
            new_row < 0
            or new_row >= self.H
            or new_col < 0
            or new_col >= self.W
            or self.reward[new_row, new_col] == -9
        ):
            return int(row), int(col)  # Stay in the same position if invalid move
        return int(new_row), int(new_col)

# Actor-Critic Model
class ActorCriticModel(tf.keras.Model):
    def __init__(self, num_actions):
        super(ActorCriticModel, self).__init__()
        self.common = layers.Dense(128, activation="relu")
        self.actor = layers.Dense(num_actions, activation="softmax")
        self.critic = layers.Dense(1)

    def call(self, inputs):
        x = self.common(inputs)
        return self.actor(x), self.critic(x)

# Training Function
def train_actor_critic(agent, model, episodes=500, gamma=0.93, learning_rate=0.0006, max_steps=100):
    optimizer = tf.keras.optimizers.Adam(learning_rate)
    total_rewards = []

    for episode in range(episodes):
        # Reset environment
        start_state = agent.generate_ini_state(agent.terminal_states[0][0], agent.terminal_states[0][1])
        state = np.array(start_state, dtype=np.float32)
        state = np.expand_dims(state, axis=0)

        episode_reward = 0
        done = False
        steps = 0

        while not done and steps < max_steps:
            steps += 1
            with tf.GradientTape() as tape:
                action_probs, state_value = model(state)

                # Choose action
                action = np.random.choice(len(agent.A), p=np.squeeze(action_probs))

                # Simulate environment step
                real_action = agent.apply_transition_function(action)
                next_state = agent.computeNextPosition(state[0, 0], state[0, 1], real_action)
                reward = agent.reward[next_state[0], next_state[1]]
                done = (np.array(next_state) == agent.terminal_states[0]).all()

                next_state = np.array(next_state, dtype=np.float32)
                next_state = np.expand_dims(next_state, axis=0)

                _, next_state_value = model(next_state)
                target = reward + gamma * next_state_value * (1 - int(done))
                td_error = target - state_value

                actor_loss = -tf.math.log(action_probs[0, action]) * td_error
                critic_loss = tf.square(td_error)
                loss = actor_loss + critic_loss

            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

            state = next_state
            episode_reward += reward

        total_rewards.append(episode_reward)
        if episode % 10 == 0:
            avg_reward = np.mean(total_rewards[-10:])
            print(f"Episode {episode}: Average Reward = {avg_reward:.2f}")

    return total_rewards

# Generate Learned Policy
def generate_learned_policy(agent, model):
    policy = np.full((agent.H, agent.W), -1)
    for row in range(agent.H):
        for col in range(agent.W):
            if agent.reward[row, col] == -9:  # Skip walls
                continue
            state = np.expand_dims(np.array([row, col], dtype=np.float32), axis=0)
            action_probs, _ = model(state)
            best_action = np.argmax(action_probs)
            policy[row, col] = best_action
    return policy

# Display Policy
def display_policy(agent, policy):
    action_map = {0: "↑", 1: "→", 2: "↓", 3: "←", -1: "█"}
    visual = np.empty(policy.shape, dtype=str)
    for row in range(agent.H):
        for col in range(agent.W):
            visual[row, col] = action_map[policy[row, col]]
    for row in visual:
        print(" ".join(row))

# Testing Function
def test_policy(agent, model):
    start_state = agent.generate_ini_state(agent.terminal_states[0][0], agent.terminal_states[0][1])
    state = np.array(start_state, dtype=np.float32)
    state = np.expand_dims(state, axis=0)
    done = False
    total_reward = 0

    while not done:
        action_probs, _ = model(state)
        action = np.argmax(action_probs)

        real_action = agent.apply_transition_function(action)
        next_state = agent.computeNextPosition(state[0, 0], state[0, 1], real_action)
        reward = agent.reward[next_state[0], next_state[1]]
        done = (np.array(next_state) == agent.terminal_states[0]).all()

        total_reward += reward
        state = np.expand_dims(np.array(next_state, dtype=np.float32), axis=0)
        print(f"State: {next_state}, Reward: {reward}")

    print(f"Total Test Reward: {total_reward}")
    return total_reward

# Plot Rewards
def plot_rewards(rewards):
    plt.plot(rewards)
    plt.xlabel('Episodes')
    plt.ylabel('Rewards')
    plt.title('Training Progress')
    plt.show()

# Main Script
if __name__ == "__main__":
    # Initialize warehouse agent
    agent = warehouse_agent(rows=2, columns=2)  # Set up a 2x2 aisle environment

    num_actions = len(agent.A)
    model = ActorCriticModel(num_actions)

    print("Training Actor-Critic...")
    rewards = train_actor_critic(agent, model, episodes=4000)

    print("Testing the learned policy...")
    test_policy(agent, model)

    print("Generating learned policy...")
    learned_policy = generate_learned_policy(agent, model)

    print("Displaying learned policy...")
    display_policy(agent, learned_policy)

    plot_rewards(rewards)
# Out:
# Training Actor-Critic...
# Episode 0: Average Reward = -100.00
# Episode 10: Average Reward = -35.30
# Episode 20: Average Reward = -44.80
# Episode 30: Average Reward = -62.40
# Episode 40: Average Reward = -72.60
# Episode 50: Average Reward = -24.90
# Episode 60: Average Reward = -48.50
# Episode 70: Average Reward = -63.60
# Episode 80: Average Reward = -41.60
# Episode 90: Average Reward = -12.00
# Episode 100: Average Reward = -8.40
# Episode 110: Average Reward = -80.00
# Episode 120: Average Reward = -63.50
# Episode 130: Average Reward = -27.70
# Episode 140: Average Reward = -50.00
# Episode 150: Average Reward = 23.30
# Episode 160: Average Reward = -84.70
# Episode 170: Average Reward = -100.00
# Episode 180: Average Reward = -82.90
# Episode 190: Average Reward = -36.70
# Episode 200: Average Reward = -33.00
# Episode 210: Average Reward = -80.80
# Episode 220: Average Reward = -14.40
# Episode 230: Average Reward = -62.40
# Episode 240: Average Reward = -62.80
# Episode 250: Average Reward = -29.10
# Episode 260: Average Reward = -29.30
# Episode 270: Average Reward = -84.10
# Episode 280: Average Reward = -80.00
# Episode 290: Average Reward = -30.10
# Episode 300: Average Reward = -33.40
# Episode 310: Average Reward = -51.30
# Episode 320: Average Reward = -60.50
# Episode 330: Average Reward = -60.40
# Episode 340: Average Reward = -63.60
# Episode 350: Average Reward = -80.00
# Episode 360: Average Reward = -35.80
# Episode 370: Average Reward = -60.80
# Episode 380: Average Reward = -1.00
# Episode 390: Average Reward = -44.90
# Episode 400: Average Reward = -80.10
# Episode 410: Average Reward = -49.60
# Episode 420: Average Reward = 1.30
# Episode 430: Average Reward = -60.40
# Episode 440: Average Reward = -27.60
# Episode 450: Average Reward = -2.90
# Episode 460: Average Reward = -45.50
# Episode 470: Average Reward = -21.60
# Episode 480: Average Reward = -16.20
# Episode 490: Average Reward = -51.60
# Episode 500: Average Reward = -62.10
# Episode 510: Average Reward = -60.50
# Episode 520: Average Reward = -33.10
# Episode 530: Average Reward = -1.80
# Episode 540: Average Reward = -33.80
# Episode 550: Average Reward = -16.40
# Episode 560: Average Reward = 24.70
# Episode 570: Average Reward = 3.10
# Episode 580: Average Reward = -85.20
# Episode 590: Average Reward = 26.40
# Episode 600: Average Reward = -31.30
# Episode 610: Average Reward = 22.40
# Episode 620: Average Reward = -3.20
# Episode 630: Average Reward = 26.50
# Episode 640: Average Reward = -1.80
# Episode 650: Average Reward = -6.50
# Episode 660: Average Reward = 10.60
# Episode 670: Average Reward = -35.90
# Episode 680: Average Reward = 9.40
# Episode 690: Average Reward = -35.70
# Episode 700: Average Reward = 23.00
# Episode 710: Average Reward = 34.70
# Episode 720: Average Reward = -35.10
# Episode 730: Average Reward = 39.30
# Episode 740: Average Reward = -37.20
# Episode 750: Average Reward = 12.50
# Episode 760: Average Reward = 39.50
# Episode 770: Average Reward = -5.80
# Episode 780: Average Reward = -8.80
# Episode 790: Average Reward = 39.20
# Episode 800: Average Reward = -7.70
# Episode 810: Average Reward = 10.80
# Episode 820: Average Reward = 30.80
# Episode 830: Average Reward = -1.00
# Episode 840: Average Reward = 13.20
# Episode 850: Average Reward = 70.10
# Episode 860: Average Reward = 28.20
# Episode 870: Average Reward = 66.50
# Episode 880: Average Reward = 53.20
# Episode 890: Average Reward = 50.80
# Episode 900: Average Reward = 5.10
# Episode 910: Average Reward = 21.80
# Episode 920: Average Reward = -4.80
# Episode 930: Average Reward = 58.70
# Episode 940: Average Reward = 67.80
# Episode 950: Average Reward = 30.40
# Episode 960: Average Reward = 68.40
# Episode 970: Average Reward = 31.90
# Episode 980: Average Reward = 66.10
# Episode 990: Average Reward = 55.60
# Episode 1000: Average Reward = 25.00
# Episode 1010: Average Reward = 57.80
# Episode 1020: Average Reward = 69.40
# Episode 1030: Average Reward = 42.80
# Episode 1040: Average Reward = 57.40
# Episode 1050: Average Reward = 72.90
# Episode 1060: Average Reward = 74.40
# Episode 1070: Average Reward = 69.80
# Episode 1080: Average Reward = 66.60
# Episode 1090: Average Reward = 57.40
# Episode 1100: Average Reward = 58.80
# Episode 1110: Average Reward = 66.60
# Episode 1120: Average Reward = 48.50
# Episode 1130: Average Reward = 84.70
# Episode 1140: Average Reward = 67.50
# Episode 1150: Average Reward = 77.80
# Episode 1160: Average Reward = 39.30
# Episode 1170: Average Reward = 64.40
# Episode 1180: Average Reward = 90.80
# Episode 1190: Average Reward = 70.20
# Episode 1200: Average Reward = 37.60
# Episode 1210: Average Reward = 76.50
# Episode 1220: Average Reward = 45.40
# Episode 1230: Average Reward = 43.50
# Episode 1240: Average Reward = 69.80
# Episode 1250: Average Reward = 55.60
# Episode 1260: Average Reward = 81.20
# Episode 1270: Average Reward = 67.90
# Episode 1280: Average Reward = 86.80
# Episode 1290: Average Reward = 84.10
# Episode 1300: Average Reward = 65.30
# Episode 1310: Average Reward = 82.10
# Episode 1320: Average Reward = 65.60
# Episode 1330: Average Reward = 42.50
# Episode 1340: Average Reward = 47.40
# Episode 1350: Average Reward = 94.80
# Episode 1360: Average Reward = 52.20
# Episode 1370: Average Reward = 70.40
# Episode 1380: Average Reward = 49.20
# Episode 1390: Average Reward = 72.30
# Episode 1400: Average Reward = 78.70
# Episode 1410: Average Reward = 51.50
# Episode 1420: Average Reward = 57.20
# Episode 1430: Average Reward = 30.80
# Episode 1440: Average Reward = 82.20
# Episode 1450: Average Reward = 52.00
# Episode 1460: Average Reward = 67.00
# Episode 1470: Average Reward = 88.20
# Episode 1480: Average Reward = 76.10
# Episode 1490: Average Reward = 67.10
# Episode 1500: Average Reward = 66.70
# Episode 1510: Average Reward = 60.30
# Episode 1520: Average Reward = 85.60
# Episode 1530: Average Reward = 44.10
# Episode 1540: Average Reward = 90.70
# Episode 1550: Average Reward = 91.20
# Episode 1560: Average Reward = 69.20
# Episode 1570: Average Reward = 73.10
# Episode 1580: Average Reward = 72.40
# Episode 1590: Average Reward = 82.00
# Episode 1600: Average Reward = 62.10
# Episode 1610: Average Reward = 53.50
# Episode 1620: Average Reward = 56.90
# Episode 1630: Average Reward = 86.50
# Episode 1640: Average Reward = 53.20
# Episode 1650: Average Reward = 72.70
# Episode 1660: Average Reward = 70.30
# Episode 1670: Average Reward = 85.80
# Episode 1680: Average Reward = 71.40
# Episode 1690: Average Reward = 47.80
# Episode 1700: Average Reward = 88.90
# Episode 1710: Average Reward = 86.40
# Episode 1720: Average Reward = 82.50
# Episode 1730: Average Reward = 61.80
# Episode 1740: Average Reward = 8.70
# Episode 1750: Average Reward = 55.30
# Episode 1760: Average Reward = 83.20
# Episode 1770: Average Reward = 73.70
# Episode 1780: Average Reward = 65.30
# Episode 1790: Average Reward = 62.60
# Episode 1800: Average Reward = 85.10
# Episode 1810: Average Reward = 64.50
# Episode 1820: Average Reward = 83.60
# Episode 1830: Average Reward = 91.90
# Episode 1840: Average Reward = 45.70
# Episode 1850: Average Reward = 26.40
# Episode 1860: Average Reward = 83.00
# Episode 1870: Average Reward = 92.50
# Episode 1880: Average Reward = 50.20
# Episode 1890: Average Reward = 71.30
# Episode 1900: Average Reward = 67.20
# Episode 1910: Average Reward = 95.10
# Episode 1920: Average Reward = 91.50
# Episode 1930: Average Reward = 67.10
# Episode 1940: Average Reward = 84.30
# Episode 1950: Average Reward = 63.60
# Episode 1960: Average Reward = 59.00
# Episode 1970: Average Reward = 93.70
# Episode 1980: Average Reward = 75.50
# Episode 1990: Average Reward = 42.50
# Episode 2000: Average Reward = 54.20
# Episode 2010: Average Reward = 72.90
# Episode 2020: Average Reward = 73.70
# Episode 2030: Average Reward = 87.10
# Episode 2040: Average Reward = 75.30
# Episode 2050: Average Reward = 95.20
# Episode 2060: Average Reward = 21.00
# Episode 2070: Average Reward = 47.50
# Episode 2080: Average Reward = 42.90
# Episode 2090: Average Reward = 67.30
# Episode 2100: Average Reward = 90.60
# Episode 2110: Average Reward = 65.10
# Episode 2120: Average Reward = 57.20
# Episode 2130: Average Reward = 75.30
# Episode 2140: Average Reward = 63.30
# Episode 2150: Average Reward = 89.70
# Episode 2160: Average Reward = 65.20
# Episode 2170: Average Reward = 90.10
# Episode 2180: Average Reward = 90.50
# Episode 2190: Average Reward = 68.30
# Episode 2200: Average Reward = 68.30
# Episode 2210: Average Reward = 66.50
# Episode 2220: Average Reward = 54.50
# Episode 2230: Average Reward = 72.00
# Episode 2240: Average Reward = 69.30
# Episode 2250: Average Reward = 62.10
# Episode 2260: Average Reward = 50.80
# Episode 2270: Average Reward = 90.10
# Episode 2280: Average Reward = 63.40
# Episode 2290: Average Reward = 45.40
# Episode 2300: Average Reward = 77.30
# Episode 2310: Average Reward = 65.60
# Episode 2320: Average Reward = 91.90
# Episode 2330: Average Reward = 58.80
# Episode 2340: Average Reward = 67.00
# Episode 2350: Average Reward = 71.90
# Episode 2360: Average Reward = 64.20
# Episode 2370: Average Reward = 62.70
# Episode 2380: Average Reward = 94.90
# Episode 2390: Average Reward = 47.10
# Episode 2400: Average Reward = 68.70
# Episode 2410: Average Reward = 35.90
# Episode 2420: Average Reward = 42.90
# Episode 2430: Average Reward = 75.00
# Episode 2440: Average Reward = 73.20
# Episode 2450: Average Reward = 71.00
# Episode 2460: Average Reward = 84.60
# Episode 2470: Average Reward = 82.70
# Episode 2480: Average Reward = 50.60
# Episode 2490: Average Reward = 16.80
# Episode 2500: Average Reward = 88.40
# Episode 2510: Average Reward = 75.90
# Episode 2520: Average Reward = 43.50
# Episode 2530: Average Reward = 10.90
# Episode 2540: Average Reward = 30.90
# Episode 2550: Average Reward = 51.70
# Episode 2560: Average Reward = 83.10
# Episode 2570: Average Reward = 48.10
# Episode 2580: Average Reward = 24.70
# Episode 2590: Average Reward = 68.40
# Episode 2600: Average Reward = 74.40
# Episode 2610: Average Reward = 83.30
# Episode 2620: Average Reward = 86.00
# Episode 2630: Average Reward = 89.10
# Episode 2640: Average Reward = 70.30
# Episode 2650: Average Reward = 74.90
# Episode 2660: Average Reward = 70.90
# Episode 2670: Average Reward = 34.00
# Episode 2680: Average Reward = 45.50
# Episode 2690: Average Reward = 70.90
# Episode 2700: Average Reward = 84.80
# Episode 2710: Average Reward = 68.70
# Episode 2720: Average Reward = 50.20
# Episode 2730: Average Reward = 75.70
# Episode 2740: Average Reward = 95.20
# Episode 2750: Average Reward = 90.20
# Episode 2760: Average Reward = 70.90
# Episode 2770: Average Reward = 87.20
# Episode 2780: Average Reward = 46.70
# Episode 2790: Average Reward = 33.70
# Episode 2800: Average Reward = 74.20
# Episode 2810: Average Reward = 90.00
# Episode 2820: Average Reward = 90.50
# Episode 2830: Average Reward = 81.90
# Episode 2840: Average Reward = 69.20
# Episode 2850: Average Reward = 93.00
# Episode 2860: Average Reward = 92.00
# Episode 2870: Average Reward = 50.30
# Episode 2880: Average Reward = 79.60
# Episode 2890: Average Reward = 92.20
# Episode 2900: Average Reward = 69.30
# Episode 2910: Average Reward = 58.30
# Episode 2920: Average Reward = 72.20
# Episode 2930: Average Reward = 74.20
# Episode 2940: Average Reward = 69.70
# Episode 2950: Average Reward = 70.70
# Episode 2960: Average Reward = 85.60
# Episode 2970: Average Reward = 61.40
# Episode 2980: Average Reward = 70.00
# Episode 2990: Average Reward = 4.60
# Episode 3000: Average Reward = 77.40
# Episode 3010: Average Reward = 71.70
# Episode 3020: Average Reward = 60.10
# Episode 3030: Average Reward = 74.30
# Episode 3040: Average Reward = 54.90
# Episode 3050: Average Reward = 29.50
# Episode 3060: Average Reward = 89.30
# Episode 3070: Average Reward = 83.10
# Episode 3080: Average Reward = 67.90
# Episode 3090: Average Reward = 28.40
# Episode 3100: Average Reward = 73.00
# Episode 3110: Average Reward = 77.30
# Episode 3120: Average Reward = 85.10
# Episode 3130: Average Reward = 67.60
# Episode 3140: Average Reward = 49.50
# Episode 3150: Average Reward = 35.00
# Episode 3160: Average Reward = 73.40
# Episode 3170: Average Reward = 54.20
# Episode 3180: Average Reward = 62.60
# Episode 3190: Average Reward = 58.90
# Episode 3200: Average Reward = 32.10
# Episode 3210: Average Reward = 55.90
# Episode 3220: Average Reward = 80.40
# Episode 3230: Average Reward = 52.10
# Episode 3240: Average Reward = 49.80
# Episode 3250: Average Reward = 76.30
# Episode 3260: Average Reward = 52.90
# Episode 3270: Average Reward = 29.90
# Episode 3280: Average Reward = 69.90
# Episode 3290: Average Reward = 64.40
# Episode 3300: Average Reward = 23.60
# Episode 3310: Average Reward = 69.70
# Episode 3320: Average Reward = 72.40
# Episode 3330: Average Reward = 91.30
# Episode 3340: Average Reward = 91.00
# Episode 3350: Average Reward = 80.40
# Episode 3360: Average Reward = 74.10
# Episode 3370: Average Reward = 55.80
# Episode 3380: Average Reward = 95.30
# Episode 3390: Average Reward = 62.10
# Episode 3400: Average Reward = 63.10
# Episode 3410: Average Reward = 91.40
# Episode 3420: Average Reward = 56.00
# Episode 3430: Average Reward = 74.70
# Episode 3440: Average Reward = 37.70
# Episode 3450: Average Reward = 84.90
# Episode 3460: Average Reward = 27.30
# Episode 3470: Average Reward = 71.70
# Episode 3480: Average Reward = 87.80
# Episode 3490: Average Reward = 70.60
# Episode 3500: Average Reward = 61.90
# Episode 3510: Average Reward = 71.60
# Episode 3520: Average Reward = 91.40
# Episode 3530: Average Reward = 66.80
# Episode 3540: Average Reward = 93.40
# Episode 3550: Average Reward = 79.00
# Episode 3560: Average Reward = 78.50
# Episode 3570: Average Reward = 90.40
# Episode 3580: Average Reward = 34.90
# Episode 3590: Average Reward = 65.50
# Episode 3600: Average Reward = 70.60
# Episode 3610: Average Reward = 89.80
# Episode 3620: Average Reward = 65.90
# Episode 3630: Average Reward = 67.80
# Episode 3640: Average Reward = 89.50
# Episode 3650: Average Reward = 63.80
# Episode 3660: Average Reward = 91.60
# Episode 3670: Average Reward = 72.00
# Episode 3680: Average Reward = 53.10
# Episode 3690: Average Reward = 85.80
# Episode 3700: Average Reward = 94.10
# Episode 3710: Average Reward = 59.70
# Episode 3720: Average Reward = 66.40
# Episode 3730: Average Reward = 91.60
# Episode 3740: Average Reward = 90.70
# Episode 3750: Average Reward = 59.50
# Episode 3760: Average Reward = 91.70
# Episode 3770: Average Reward = 47.60
# Episode 3780: Average Reward = 73.80
# Episode 3790: Average Reward = 71.90
# Episode 3800: Average Reward = 87.30
# Episode 3810: Average Reward = 86.80
# Episode 3820: Average Reward = 63.00
# Episode 3830: Average Reward = 84.20
# Episode 3840: Average Reward = 64.00
# Episode 3850: Average Reward = 64.50
# Episode 3860: Average Reward = 46.90
# Episode 3870: Average Reward = 89.30
# Episode 3880: Average Reward = 45.20
# Episode 3890: Average Reward = 84.50
# Episode 3900: Average Reward = 56.20
# Episode 3910: Average Reward = 41.00
# Episode 3920: Average Reward = 72.50
# Episode 3930: Average Reward = 71.30
# Episode 3940: Average Reward = 69.90
# Episode 3950: Average Reward = 87.10
# Episode 3960: Average Reward = 81.80
# Episode 3970: Average Reward = 93.50
# Episode 3980: Average Reward = 83.90
# Episode 3990: Average Reward = 54.30
# Testing the learned policy...
# State: (3, 0), Reward: -1.0
# State: (2, 0), Reward: -1.0
# State: (1, 0), Reward: -1.0
# State: (0, 0), Reward: -1.0
# State: (0, 1), Reward: -1.0
# State: (0, 2), Reward: -1.0
# State: (1, 2), Reward: -1.0
# State: (2, 2), Reward: 100.0
# Total Test Reward: 93.0
# Generating learned policy...
# Displaying learned policy...
# → → ↓ ← ← ← ← ←
# ↑ █ ↓ █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ ←
# ↑ ↑ ↑ ← ← ← ← ←
# ↑ █ ↑ █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ ←
# ↑ ↑ ↑ ← ← ← ← ←
