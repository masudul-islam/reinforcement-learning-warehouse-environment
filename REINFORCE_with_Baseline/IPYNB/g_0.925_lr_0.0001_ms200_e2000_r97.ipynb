# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Warehouse Agent
class warehouse_agent:
    def __init__(self, rows, columns):
        self.A = np.array([0, 1, 2, 3])  # Actions: ['Up', 'Right', 'Down', 'Left']
        self.P = np.array([0.95, 0.97, 0.99, 1.0])  # Reduced stochasticity
        self.rows = rows
        self.columns = columns
        self.reward = None
        self.terminal_states = None
        self.H = None  # environment height
        self.W = None  # environment width
        self._generate_environment(rows, columns)

    def _generate_environment(self, rows, columns):
        self.H = 3 * rows + rows + 1
        self.W = 3 * columns + 2
        reward = -np.ones((self.H, self.W))
        reward[:, np.arange(1, self.W - 3, 3)] = -9
        reward[:, np.arange(3, self.W, 3)] = -9
        reward[np.arange(0, self.H, 4)] = -1
        reward[2, 2] = 100
        self.reward = reward
        self.terminal_states = np.array([[2, 2]])

    def generate_ini_state(self, terminate_x, terminate_y):
        while True:
            x = np.random.randint(0, self.H)
            y = np.random.randint(0, self.W)
            if (x, y) != (terminate_x, terminate_y) and self.reward[x, y] != -9:
                return [x, y]

    def apply_transition_function(self, intended_action):
        c = np.random.rand()
        if c < self.P[0]:
            return intended_action
        elif c < self.P[1]:
            return (intended_action - 1) % len(self.A)
        elif c < self.P[2]:
            return (intended_action + 1) % len(self.A)
        else:
            return None

    def computeNextPosition(self, row, col, action):
        if action is None:
            return int(row), int(col)

        new_row, new_col = int(row), int(col)
        if action == 0:
            new_row -= 1
        elif action == 1:
            new_col += 1
        elif action == 2:
            new_row += 1
        elif action == 3:
            new_col -= 1

        if (
            new_row < 0
            or new_row >= self.H
            or new_col < 0
            or new_col >= self.W
            or self.reward[new_row, new_col] == -9
        ):
            return int(row), int(col)
        return int(new_row), int(new_col)


# Policy Network for REINFORCE
class PolicyNetwork(tf.keras.Model):
    def __init__(self, num_actions):
        super(PolicyNetwork, self).__init__()
        self.dense1 = layers.Dense(128, activation="relu")
        self.policy_logits = layers.Dense(num_actions, activation="softmax")

    def call(self, inputs):
        x = self.dense1(inputs)
        return self.policy_logits(x)


# Value Network (Baseline) for REINFORCE
class ValueNetwork(tf.keras.Model):
    def __init__(self):
        super(ValueNetwork, self).__init__()
        self.dense1 = layers.Dense(128, activation="relu")
        self.value = layers.Dense(1)

    def call(self, inputs):
        x = self.dense1(inputs)
        return self.value(x)


# Training REINFORCE with Baseline
def train_reinforce_with_baseline(agent, policy_model, value_model, episodes=500, gamma=0.925, learning_rate=0.0001, max_steps=200):
    policy_optimizer = tf.keras.optimizers.Adam(learning_rate)
    value_optimizer = tf.keras.optimizers.Adam(learning_rate)
    total_rewards = []

    for episode in range(episodes):
        state = agent.generate_ini_state(agent.terminal_states[0][0], agent.terminal_states[0][1])
        state = np.expand_dims(np.array(state, dtype=np.float32), axis=0)

        episode_states, episode_actions, episode_rewards = [], [], []
        done = False
        steps = 0

        while not done and steps < max_steps:
            steps += 1
            action_probs = policy_model(state)
            action = np.random.choice(len(agent.A), p=np.squeeze(action_probs))
            real_action = agent.apply_transition_function(action)
            next_state = agent.computeNextPosition(state[0, 0], state[0, 1], real_action)
            reward = agent.reward[next_state[0], next_state[1]]
            done = (np.array(next_state) == agent.terminal_states[0]).all()

            episode_states.append(state)
            episode_actions.append(action)
            episode_rewards.append(reward)

            state = np.expand_dims(np.array(next_state, dtype=np.float32), axis=0)

        total_rewards.append(sum(episode_rewards))
        returns = compute_discounted_rewards(episode_rewards, gamma)

        for state, action, G in zip(episode_states, episode_actions, returns):
            with tf.GradientTape(persistent=True) as tape:
                state_value = value_model(state)
                action_probs = policy_model(state)
                advantage = G - state_value

                policy_loss = -tf.math.log(action_probs[0, action]) * advantage
                value_loss = tf.square(advantage)

            policy_grads = tape.gradient(policy_loss, policy_model.trainable_variables)
            value_grads = tape.gradient(value_loss, value_model.trainable_variables)
            policy_optimizer.apply_gradients(zip(policy_grads, policy_model.trainable_variables))
            value_optimizer.apply_gradients(zip(value_grads, value_model.trainable_variables))

        if episode % 10 == 0:
            avg_reward = np.mean(total_rewards[-10:])
            print(f"Episode {episode}: Average Reward = {avg_reward:.2f}")

    return total_rewards


# Compute Discounted Rewards
def compute_discounted_rewards(rewards, gamma):
    discounted_rewards = np.zeros_like(rewards, dtype=np.float32)
    cumulative = 0
    for t in reversed(range(len(rewards))):
        cumulative = cumulative * gamma + rewards[t]
        discounted_rewards[t] = cumulative
    return discounted_rewards


# Generate Learned Policy
def generate_learned_policy(agent, policy_model):
    policy = np.full((agent.H, agent.W), -1)
    for row in range(agent.H):
        for col in range(agent.W):
            if agent.reward[row, col] == -9:
                continue
            state = np.expand_dims(np.array([row, col], dtype=np.float32), axis=0)
            action_probs = policy_model(state)
            best_action = np.argmax(action_probs)
            policy[row, col] = best_action
    return policy


# Display Policy with Arrows
def display_policy_with_arrows(agent, policy):
    action_map = {0: "↑", 1: "→", 2: "↓", 3: "←", -1: "█"}
    visual = np.empty(policy.shape, dtype=str)
    for row in range(agent.H):
        for col in range(agent.W):
            visual[row, col] = action_map[policy[row, col]]
    for row in visual:
        print(" ".join(row))


# Plot Heatmap
def plot_heatmap(agent, policy):
    plt.figure(figsize=(10, 6))
    plt.imshow(policy, cmap="viridis", interpolation="nearest")
    plt.colorbar(label="Action Index")
    plt.title("Heatmap of Learned Policy")
    plt.show()


# Plot Rewards
def plot_rewards(rewards):
    plt.plot(rewards)
    plt.xlabel("Episodes")
    plt.ylabel("Rewards")
    plt.title("Training Progress")
    plt.show()


# Testing the Learned Policy
def test_policy(agent, policy_model):
    state = agent.generate_ini_state(agent.terminal_states[0][0], agent.terminal_states[0][1])
    state = np.expand_dims(np.array(state, dtype=np.float32), axis=0)
    total_reward = 0
    done = False

    while not done:
        action_probs = policy_model(state)
        action = np.argmax(action_probs)
        real_action = agent.apply_transition_function(action)
        next_state = agent.computeNextPosition(state[0, 0], state[0, 1], real_action)
        reward = agent.reward[next_state[0], next_state[1]]
        done = (np.array(next_state) == agent.terminal_states[0]).all()
        total_reward += reward
        state = np.expand_dims(np.array(next_state, dtype=np.float32), axis=0)
    print(f"Total Test Reward: {total_reward}")


# Main Script
if __name__ == "__main__":
    agent = warehouse_agent(rows=2, columns=2)
    policy_model = PolicyNetwork(len(agent.A))
    value_model = ValueNetwork()

    print("Training REINFORCE with Baseline...")
    rewards = train_reinforce_with_baseline(agent, policy_model, value_model, episodes=2000)

    print("Testing the learned policy...")
    test_policy(agent, policy_model)

    print("Generating Learned Policy...")
    learned_policy = generate_learned_policy(agent, policy_model)

    print("Displaying Learned Policy with Arrows...")
    display_policy_with_arrows(agent, learned_policy)

    print("Plotting Heatmap of Learned Policy...")
    plot_heatmap(agent, learned_policy)

    print("Plotting Training Rewards...")
    plot_rewards(rewards)
# Out:
# Training REINFORCE with Baseline...
# Episode 0: Average Reward = -200.00
# Episode 10: Average Reward = -181.70
# Episode 20: Average Reward = -170.60
# Episode 30: Average Reward = -150.20
# Episode 40: Average Reward = -95.20
# Episode 50: Average Reward = -45.30
# Episode 60: Average Reward = -34.90
# Episode 70: Average Reward = 20.90
# Episode 80: Average Reward = -18.00
# Episode 90: Average Reward = 24.20
# Episode 100: Average Reward = 42.00
# Episode 110: Average Reward = 57.00
# Episode 120: Average Reward = 61.20
# Episode 130: Average Reward = 47.90
# Episode 140: Average Reward = 49.40
# Episode 150: Average Reward = 56.50
# Episode 160: Average Reward = 57.50
# Episode 170: Average Reward = 66.50
# Episode 180: Average Reward = 77.90
# Episode 190: Average Reward = 65.10
# Episode 200: Average Reward = 46.50
# Episode 210: Average Reward = 50.90
# Episode 220: Average Reward = 55.80
# Episode 230: Average Reward = 65.20
# Episode 240: Average Reward = 75.50
# Episode 250: Average Reward = 61.10
# Episode 260: Average Reward = 55.40
# Episode 270: Average Reward = 77.40
# Episode 280: Average Reward = 71.90
# Episode 290: Average Reward = 55.10
# Episode 300: Average Reward = 81.70
# Episode 310: Average Reward = 65.90
# Episode 320: Average Reward = 64.80
# Episode 330: Average Reward = 72.60
# Episode 340: Average Reward = 62.90
# Episode 350: Average Reward = 71.10
# Episode 360: Average Reward = 73.10
# Episode 370: Average Reward = 74.00
# Episode 380: Average Reward = 81.70
# Episode 390: Average Reward = 82.70
# Episode 400: Average Reward = 65.20
# Episode 410: Average Reward = 49.60
# Episode 420: Average Reward = 73.90
# Episode 430: Average Reward = 58.60
# Episode 440: Average Reward = 72.40
# Episode 450: Average Reward = 53.30
# Episode 460: Average Reward = 61.00
# Episode 470: Average Reward = 55.70
# Episode 480: Average Reward = 79.80
# Episode 490: Average Reward = 71.90
# Episode 500: Average Reward = 81.70
# Episode 510: Average Reward = 87.60
# Episode 520: Average Reward = 44.70
# Episode 530: Average Reward = 69.30
# Episode 540: Average Reward = 70.70
# Episode 550: Average Reward = 84.90
# Episode 560: Average Reward = 62.10
# Episode 570: Average Reward = 77.10
# Episode 580: Average Reward = 70.50
# Episode 590: Average Reward = 78.40
# Episode 600: Average Reward = 74.40
# Episode 610: Average Reward = 73.10
# Episode 620: Average Reward = 91.00
# Episode 630: Average Reward = 76.30
# Episode 640: Average Reward = 71.40
# Episode 650: Average Reward = 75.90
# Episode 660: Average Reward = 66.70
# Episode 670: Average Reward = 79.70
# Episode 680: Average Reward = 74.60
# Episode 690: Average Reward = 75.60
# Episode 700: Average Reward = 72.60
# Episode 710: Average Reward = 66.90
# Episode 720: Average Reward = 77.90
# Episode 730: Average Reward = 65.60
# Episode 740: Average Reward = 40.10
# Episode 750: Average Reward = 67.30
# Episode 760: Average Reward = 53.90
# Episode 770: Average Reward = 71.30
# Episode 780: Average Reward = 78.40
# Episode 790: Average Reward = 84.80
# Episode 800: Average Reward = 79.90
# Episode 810: Average Reward = 83.80
# Episode 820: Average Reward = 80.10
# Episode 830: Average Reward = 82.70
# Episode 840: Average Reward = 49.40
# Episode 850: Average Reward = 79.60
# Episode 860: Average Reward = 61.20
# Episode 870: Average Reward = 75.30
# Episode 880: Average Reward = 77.90
# Episode 890: Average Reward = 84.00
# Episode 900: Average Reward = 63.10
# Episode 910: Average Reward = 79.90
# Episode 920: Average Reward = 74.40
# Episode 930: Average Reward = 65.50
# Episode 940: Average Reward = 85.90
# Episode 950: Average Reward = 78.00
# Episode 960: Average Reward = 74.50
# Episode 970: Average Reward = 83.30
# Episode 980: Average Reward = 67.90
# Episode 990: Average Reward = 82.60
# Episode 1000: Average Reward = 70.50
# Episode 1010: Average Reward = 77.50
# Episode 1020: Average Reward = 86.50
# Episode 1030: Average Reward = 83.60
# Episode 1040: Average Reward = 78.10
# Episode 1050: Average Reward = 60.30
# Episode 1060: Average Reward = 87.00
# Episode 1070: Average Reward = 85.20
# Episode 1080: Average Reward = 72.70
# Episode 1090: Average Reward = 88.10
# Episode 1100: Average Reward = 83.40
# Episode 1110: Average Reward = 65.70
# Episode 1120: Average Reward = 73.20
# Episode 1130: Average Reward = 81.20
# Episode 1140: Average Reward = 68.60
# Episode 1150: Average Reward = 74.80
# Episode 1160: Average Reward = 82.40
# Episode 1170: Average Reward = 82.10
# Episode 1180: Average Reward = 83.80
# Episode 1190: Average Reward = 82.60
# Episode 1200: Average Reward = 86.00
# Episode 1210: Average Reward = 70.10
# Episode 1220: Average Reward = 71.50
# Episode 1230: Average Reward = 59.20
# Episode 1240: Average Reward = 78.30
# Episode 1250: Average Reward = 71.60
# Episode 1260: Average Reward = 70.00
# Episode 1270: Average Reward = 85.40
# Episode 1280: Average Reward = 85.10
# Episode 1290: Average Reward = 74.80
# Episode 1300: Average Reward = 82.40
# Episode 1310: Average Reward = 64.60
# Episode 1320: Average Reward = 60.90
# Episode 1330: Average Reward = 63.80
# Episode 1340: Average Reward = 83.30
# Episode 1350: Average Reward = 68.20
# Episode 1360: Average Reward = 69.70
# Episode 1370: Average Reward = 62.60
# Episode 1380: Average Reward = 84.50
# Episode 1390: Average Reward = 50.10
# Episode 1400: Average Reward = 71.10
# Episode 1410: Average Reward = 65.40
# Episode 1420: Average Reward = 74.60
# Episode 1430: Average Reward = 90.80
# Episode 1440: Average Reward = 65.50
# Episode 1450: Average Reward = 74.20
# Episode 1460: Average Reward = 59.80
# Episode 1470: Average Reward = 82.40
# Episode 1480: Average Reward = 85.90
# Episode 1490: Average Reward = 72.60
# Episode 1500: Average Reward = 87.90
# Episode 1510: Average Reward = 78.80
# Episode 1520: Average Reward = 74.70
# Episode 1530: Average Reward = 79.50
# Episode 1540: Average Reward = 59.00
# Episode 1550: Average Reward = 80.10
# Episode 1560: Average Reward = 88.00
# Episode 1570: Average Reward = 76.50
# Episode 1580: Average Reward = 77.40
# Episode 1590: Average Reward = 76.40
# Episode 1600: Average Reward = 28.70
# Episode 1610: Average Reward = 46.80
# Episode 1620: Average Reward = 67.10
# Episode 1630: Average Reward = 66.30
# Episode 1640: Average Reward = 73.20
# Episode 1650: Average Reward = 73.50
# Episode 1660: Average Reward = 82.20
# Episode 1670: Average Reward = 72.20
# Episode 1680: Average Reward = 78.80
# Episode 1690: Average Reward = 83.80
# Episode 1700: Average Reward = 77.60
# Episode 1710: Average Reward = 72.20
# Episode 1720: Average Reward = 76.20
# Episode 1730: Average Reward = 65.70
# Episode 1740: Average Reward = 68.60
# Episode 1750: Average Reward = 67.30
# Episode 1760: Average Reward = 69.00
# Episode 1770: Average Reward = 63.70
# Episode 1780: Average Reward = 76.70
# Episode 1790: Average Reward = 76.70
# Episode 1800: Average Reward = 73.10
# Episode 1810: Average Reward = 66.60
# Episode 1820: Average Reward = 77.70
# Episode 1830: Average Reward = 80.90
# Episode 1840: Average Reward = 79.30
# Episode 1850: Average Reward = 75.70
# Episode 1860: Average Reward = 63.80
# Episode 1870: Average Reward = 87.00
# Episode 1880: Average Reward = 76.00
# Episode 1890: Average Reward = 73.60
# Episode 1900: Average Reward = 76.30
# Episode 1910: Average Reward = 75.70
# Episode 1920: Average Reward = 79.50
# Episode 1930: Average Reward = 69.00
# Episode 1940: Average Reward = 82.40
# Episode 1950: Average Reward = 79.50
# Episode 1960: Average Reward = 56.10
# Episode 1970: Average Reward = 84.70
# Episode 1980: Average Reward = 77.50
# Episode 1990: Average Reward = 72.20
# Testing the learned policy...
# Total Test Reward: 97.0
# Generating Learned Policy...
# Displaying Learned Policy with Arrows...
# → ↓ ↓ ↓ ↓ ↓ ↓ ↓
# ↑ █ ↓ █ █ ↓ █ ↓
# ↑ █ ← █ █ ← █ ↓
# ↑ █ ↑ █ █ ← █ ←
# ↑ ↑ ↑ ↑ ← ← ← ←
# ↑ █ ↑ █ █ ← █ ←
# ↑ █ ↑ █ █ ← █ ←
# ↑ █ ↑ █ █ ↑ █ ←
# ↑ ↑ ↑ ↑ ↑ ↑ ↑ ←
# Plotting Heatmap of Learned Policy...
# Plotting Training Rewards...
